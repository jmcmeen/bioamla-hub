# %% [markdown]
# # PyTorch GPU Test
#
# Tests if PyTorch is installed with CUDA/GPU capabilities.

# %%
import torch

cuda_available = torch.cuda.is_available()
current_device = torch.cuda.current_device()
device_count = torch.cuda.device_count()
device_name = torch.cuda.get_device_name(0)

print(f'cuda available: {cuda_available}')
print(f'current device: {current_device}')
print(f'device count: {device_count}')
print(f'device name: {device_name}')
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[1], line 4
#       1 import torch
#       3 cuda_available = torch.cuda.is_available()
# ----> 4 current_device = torch.cuda.current_device()
#       5 device_count = torch.cuda.device_count()
#       6 device_name = torch.cuda.get_device_name(0)
#
# File c:\Users\johnm\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\cuda\__init__.py:1071, in current_device()
#    1069 def current_device() -> int:
#    1070     r"""Return the index of a currently selected device."""
# -> 1071     _lazy_init()
#    1072     return torch._C._cuda_getDevice()
#
# File c:\Users\johnm\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\cuda\__init__.py:403, in _lazy_init()
#     398     raise RuntimeError(
#     399         "Cannot re-initialize CUDA in forked subprocess. To use CUDA with "
#     400         "multiprocessing, you must use the 'spawn' start method"
#     401     )
#     402 if not hasattr(torch._C, "_cuda_getDeviceCount"):
# --> 403     raise AssertionError("Torch not compiled with CUDA enabled")
#     404 if _cudart is None:
#     405     raise AssertionError(
#     406         "libcudart functions unavailable. It looks like you have a broken build?"
#     407     )
#
# AssertionError: Torch not compiled with CUDA enabled

# %%
import torch
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
print()

#Additional Info when using cuda
if device.type == 'cuda':
    print(torch.cuda.get_device_name(0))
    print('Memory Usage:')
    print('Allocated:', round(torch.cuda.memory_allocated(0)/1024**3,1), 'GB')
    print('Cached:   ', round(torch.cuda.memory_reserved(0)/1024**3,1), 'GB')
# Out:
# Using device: cuda
#
# NVIDIA GeForce RTX 4060 Ti
# Memory Usage:
# Allocated: 0.0 GB
# Cached:    0.0 GB
